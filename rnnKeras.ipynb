# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import numpy as np 
import pandas as pd

# %%
# %pip install keras

# %%
docs = [
    'go india',
    'india india',
    'hip hip hurray',
    'jeetega bhai jeetega india hi jeetega',
    'inquilab zindabad',
    'allah hu akbar',
    'this is a test text',
    'this text is for test purpose'
]

# %%
# %pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 64.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 98.6 MB/s eta 0:00:00
# ...

# %%
import pdfplumber
data = []
with pdfplumber.open('Anime_Recommendation_System_Roadmap.pdf') as pdf:
    for page in pdf.page:
        text = page.extract_text()
        data.append(text)
df = pd.DataFrame(data, columns=['PageTexts'])
print(df.head(2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1278732217.py in <cell line: 0>()
#       1 import pdfplumber
#       2 data = []
# ----> 3 with pdfplumber.open('Anime_Recommendation_System_Roadmap.pdf') as pdf:
#       4     for page in pdf.page:
#       5         text = page.extract_text()
#
# /usr/local/lib/python3.12/dist-packages/pdfplumber/pdf.py in open(cls, path_or_fp, pages, laparams, password, strict_metadata, unicode_norm, repair, gs_path, repair_setting, raise_unicode_errors)
#      96             path = None
#      97         elif isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 98             stream = open(path_or_fp, "rb")
#      99             stream_is_external = False
#     100             path = pathlib.Path(path_or_fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Anime_Recommendation_System_Roadmap.pdf'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='Danish')

# %%
tokenizer.fit_on_texts(docs)

# %%
docs
# Out:
# ['go india',
#  'india india',
#  'hip hip hurray',
#  'jeetega bhai jeetega india hi jeetega',
#  'inquilab zindabad',
#  'allah hu akbar',
#  'this is a test text',
#  'this text is for test purpose']

# %%
tokenizer.word_index
# Out:
# {'Danish': 1,
#  'india': 2,
#  'jeetega': 3,
#  'hip': 4,
#  'this': 5,
#  'is': 6,
#  'test': 7,
#  'text': 8,
#  'go': 9,
#  'hurray': 10,
#  'bhai': 11,
#  'hi': 12,
#  'inquilab': 13,
#  'zindabad': 14,
#  'allah': 15,
#  'hu': 16,
#  'akbar': 17,
#  'a': 18,
#  'for': 19,
#  'purpose': 20}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 4),
#              ('hip', 2),
#              ('hurray', 1),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('hi', 1),
#              ('inquilab', 1),
#              ('zindabad', 1),
#              ('allah', 1),
#              ('hu', 1),
#              ('akbar', 1),
#              ('this', 2),
#              ('is', 2),
#              ('a', 1),
#              ('test', 2),
#              ('text', 2),
#              ('for', 1),
#              ('purpose', 1)])
